# %% [markdown]
# # Using Pandas for Reading spreadsheets

# %%
# importing the required libraries

import pandas as pd

# reading the dataset 
df=pd.read_excel('taddmcases.xlsx')

# %%
df.head()
# Out:
#    Case Number  Case Age                                            Subject  \
# 0  TS004003869         9  TADDM 7.3 Secondary Storage Server fails to start
# 1  TS002294716       442                    TADDM Scan is running very SLOW
# 2  TS002604126       361  ProductName and ProductVersion missing for Web...
# 3  TS002806036       311  SessionClientException: CreateProcess failed: ...
# 4  TS003047284       260                 Issue in viewing custom Topologies
#
#                                         Account Name  \
# 0                          Total System Services LLC
# 1                          IGS c/o IBM Corp GCMS-001
# 2  AVP Only CITIGROUP Technology Inc. (TIVOLI OPP...
# 3                                          ThinkTech
# 4                           Ericsson AB (MEW Kuwait)
#
#                                       Severity Level                  Status  \
# 0  1 - Critical business impact (production or se...  Awaiting your feedback
# ...

# %%
df.columns
# Out:
# Index(['Case Number', 'Case Age', 'Subject', 'Account Name', 'Severity Level',
#        'Status', 'Date/Time Opened', 'First Support Response',
#        'Last Modified Work Item Date', 'Days since last modification',
#        'Owner Name', 'Last Customer Comment', 'Last Support Post',
#        'Last Modified By Alias'],
#       dtype='object')

# %%
df[df['Owner Name']=='Ansari, Mohammed']
# Out:
#     Case Number  Case Age                                            Subject  \
# 18  TS003937133        25                     Lost Ability to scan a VCenter
# 20  TS003978049        15  startServer.bat System error 1069 has occurred...
# 25  TS003927850        27  SSL enable SSL access of the server by the Con...
# 56  TS004010741         7  Topology and explorer views are not working in...
# 59  TS004021991         3  TADDM, SSL Keystore/Certificates and externall...
# 64  TS003999961        10                 TADDM environment growth assesment
# 66  TS004016882         4                                 DLA failing to run
# 74  TS004005581         8  Discovered Components (Business Apps) Delete T...
# 75  TS004025866         3      We are getting core dumps on discovery server
#
#                                          Account Name  \
# 18                          IGS c/o IBM Corp GCMS-001
# 20                                 THE CREATECH GROUP
# ...

# %%
df2=df[df['Owner Name']=='Ansari, Mohammed'] 

df2[['Owner Name', 'Days since last modification', 'Case Age']]
# Out:
#           Owner Name  Days since last modification  Case Age
# 18  Ansari, Mohammed                             1        25
# 20  Ansari, Mohammed                             2        15
# 25  Ansari, Mohammed                             2        27
# 56  Ansari, Mohammed                             4         7
# 59  Ansari, Mohammed                             1         3
# 64  Ansari, Mohammed                             3        10
# 66  Ansari, Mohammed                             2         4
# 74  Ansari, Mohammed                             4         8
# 75  Ansari, Mohammed                             3         3

# %%
#Selecting rows by their position
df2.iloc[:3]
# Out:
#     Case Number  Case Age                                            Subject  \
# 18  TS003937133        25                     Lost Ability to scan a VCenter
# 20  TS003978049        15  startServer.bat System error 1069 has occurred...
# 25  TS003927850        27  SSL enable SSL access of the server by the Con...
#
#                                          Account Name  \
# 18                          IGS c/o IBM Corp GCMS-001
# 20                                 THE CREATECH GROUP
# 25  Etisalat Services Holding LLC Emirates Telecom...
#
#                                  Severity Level                  Status  \
# 18  2 - Significant impact (any system is down)         Waiting for IBM
# 20  2 - Significant impact (any system is down)  Awaiting your feedback
# 25  2 - Significant impact (any system is down)  Awaiting your feedback
#
#       Date/Time Opened First Support Response  Last Modified Work Item Date  \
# ...

# %%
# selecting columns by their positions
df2.iloc[:,:2]
# Out:
#     Case Number  Case Age
# 18  TS003937133        25
# 20  TS003978049        15
# 25  TS003927850        27
# 56  TS004010741         7
# 59  TS004021991         3
# 64  TS003999961        10
# 66  TS004016882         4
# 74  TS004005581         8
# 75  TS004025866         3

# %%
#importing pandas

import pandas as pd

index=pd.read_csv('index.csv')
index.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J', 'K', 'L'], dtype='object')

# %%
#Accessing the third column of index dataframe

index['C']
# Out:
# 0       8
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 252     0
# 253     6
# 254     0
# 255    45
# 256     6
# Name: C, Length: 257, dtype: int64

# %%
# Accessing last two columns using iloc function

index.iloc[:,-2:]
# Out:
#      K  L
# 0    0  3
# 1    0  3
# 2    0  3
# 3    0  3
# 4    0  3
# ..  .. ..
# 252  0  3
# 253  0  3
# 254  0  3
# 255  0  3
# 256  0  3
#
# [257 rows x 2 columns]

# %%
#Accessing last ten rows and first two columns of index dataframe

index.iloc[247:257,0:2]

#index2=index.tail(10)

#index2.column['A','B']
#index.iloc[9:,:2]
# Out:
#      A  B
# 247  C  R
# 248  C  A
# 249  C  A
# 250  C  R
# 251  C  A
# 252  C  A
# 253  C  R
# 254  C  A
# 255  C  K
# 256  C  R
